# %% [markdown]
# # NuFrost Evaluation Notebook
# This notebook runs the accuracy assessment for NuFrost, Zhu2015, and HANTS algorithms using simulated gap experiments.

# %%
from google.colab import drive # type: ignore[import]
import os

drive.mount('/content/drive')
MOUNT_POINT_IN_COLAB = "/content/drive"
PROJECT_PATH_IN_GDRIVE = "WorkSpaces/nufrost"
PROJECT_DIR = os.path.join(MOUNT_POINT_IN_COLAB, "MyDrive", PROJECT_PATH_IN_GDRIVE)

os.chdir(PROJECT_DIR)
print(f"[Success] Working directory changed to: {os.getcwd()}")

# %%
# %pip install -r requirements.txt
# %pip install scikit-image

# %%
import importlib
import src.evaluation
from config import build_args
import pandas as pd
from IPython.display import display

# Ensure the latest version of the module is loaded
importlib.reload(src.evaluation)

# Define paths (Adjust IMAGE_FILENAME to the image you want to evaluate)
DATA_PATH_IN_GDRIVE = "EEExport/"
IMAGE_FILENAME = "COPERNICUS_S2_HARMONIZED_B8_lon94.3610_lat29.6483.tif" # Example file
IMAGE_PATH = os.path.join(MOUNT_POINT_IN_COLAB, "MyDrive", DATA_PATH_IN_GDRIVE, IMAGE_FILENAME)

print(f"Target Image: {IMAGE_PATH}")
if not os.path.exists(IMAGE_PATH):
    print("File not found! Please check IMAGE_FILENAME.")

# %%
print("========== Starting Accuracy Assessment ==========")

# 1. Initialize arguments
args = build_args([])
args.image = IMAGE_PATH
args.n_jobs = -1  # Use all available cores in Colab

# 2. Run evaluation
# top_k_slices: Number of best-quality time slices (least NaNs) to test on.
# mask_ratio: Percentage of the image to mask out.
# mask_type: 'block' for large cloud simulation, 'random' for scattered missing data.
df_results = src.evaluation.evaluate_algorithms(
    image_path=args.image,
    args=args,
    mask_type="block",
    mask_ratio=0.3,
    top_k_slices=2
)

# 3. Display results nicely
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
display(df_results)
